# %% [markdown]
# <a href="https://colab.research.google.com/github/ferranfont/sp500/blob/main/feed_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alphan Vantage API KEY : S3DCI8BVT4ZHI0EI

# %%
pip install alpha_vantage
# Out:
# Requirement already satisfied: alpha_vantage in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from alpha_vantage) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from alpha_vantage) (2.23.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (21.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (3.10.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->alpha_vantage) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp->alpha_vantage) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->alpha_vantage) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->alpha_vantage) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->alpha_vantage) (1.24.3)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %%
API_key = 'S3DCI8BVT4ZHI0EI'
ts = TimeSeries(key = API_key, output_format='pandas')

# %%
simolo = 'MSF'
data = ts.get_weekly_adjusted(simbolo)
datos =data[0]

# %%
datos['1. open']
# Out:
# date
# 2022-03-11    456.22
# 2022-03-04    462.40
# 2022-02-25    440.35
# 2022-02-18    473.20
# 2022-02-11    516.00
#                ...
# 1999-12-10     66.50
# 1999-12-03     72.25
# 1999-11-26     75.13
# 1999-11-19     75.94
# 1999-11-12     69.94
# Name: 1. open, Length: 1166, dtype: float64

# %%
df = pd.DataFrame(datos)
df
# Out:
#             1. open   2. high    3. low  4. close  5. adjusted close  \
# date
# 2022-03-11   456.22  457.6800  415.4300    416.38           416.3800
# 2022-03-04   462.40  479.2100  447.0000    452.13           452.1300
# 2022-02-25   440.35  468.5199  416.8124    465.54           465.5400
# 2022-02-18   473.20  482.5337  441.7700    442.56           442.5600
# 2022-02-11   516.00  522.4800  472.8952    473.97           473.9700
# ...             ...       ...       ...       ...                ...
# 1999-12-10    66.50   70.8800   59.8800     62.63            15.5443
# 1999-12-03    72.25   74.0600   66.3100     66.69            16.5520
# 1999-11-26    75.13   76.7500   72.6100     73.81            18.3191
# 1999-11-19    75.94   79.0000   72.9400     75.63            18.7708
# 1999-11-12    69.94   75.8800   69.7500     75.13            18.6467
#
#              6. volume  7. dividend amount
# date
# 2022-03-11  17473378.0                 0.0
# 2022-03-04  15262046.0                 0.0
# 2022-02-25  17719303.0                 0.0
# 2022-02-18  20083222.0                 0.0
# 2022-02-11  18631453.0                 0.0
# ...                ...                 ...
# 1999-12-10  14699600.0                 0.0
# 1999-12-03  11811700.0                 0.0
# 1999-11-26   4601900.0                 0.0
# 1999-11-19   8908300.0                 0.0
# 1999-11-12   6473200.0                 0.0
#
# [1166 rows x 7 columns]

# %%
my_columns =['open','high','low','close','adj_close','Volume','dividend']
df.columns= my_columns

# %%
df.head(10)
# Out:
#               open      high       low   close  adj_close      Volume  \
# date
# 2022-03-11  456.22  457.6800  415.4300  416.38     416.38  17473378.0
# 2022-03-04  462.40  479.2100  447.0000  452.13     452.13  15262046.0
# 2022-02-25  440.35  468.5199  416.8124  465.54     465.54  17719303.0
# 2022-02-18  473.20  482.5337  441.7700  442.56     442.56  20083222.0
# 2022-02-11  516.00  522.4800  472.8952  473.97     473.97  18631453.0
# 2022-02-04  518.98  540.4600  503.7700  513.54     513.54  14439098.0
# 2022-01-28  491.07  520.4900  480.6200  518.16     518.16  26265780.0
# 2022-01-21  510.39  532.0250  499.2701  499.91     499.91  13859586.0
# 2022-01-14  500.00  541.5900  497.0100  520.60     520.60  17744107.0
# 2022-01-07  566.65  575.0000  504.0000  510.70     510.70  22122110.0
#
#             dividend
# date
# 2022-03-11       0.0
# 2022-03-04       0.0
# 2022-02-25       0.0
# 2022-02-18       0.0
# 2022-02-11       0.0
# 2022-02-04       0.0
# 2022-01-28       0.0
# 2022-01-21       0.0
# 2022-01-14       0.0
# 2022-01-07       0.0

# %%
#visualize data in a chart
plt.figure(figsize=(28,8))
plt.title('Precios de Apple al cierre')
plt.xlabel('Fecha',fontsize=16)
plt.ylabel('Precios de cierre',fontsize=16)
plt.plot(df['close'])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
acciones_full = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/sp500_excell.xlsx')
acciones_full
# Out:
#     symbol                  companyName
# 0        A    Agilent Technologies Inc.
# 1      AAL  American Airlines Group Inc
# 2      AAP       Advance Auto Parts Inc
# 3     AAPL                    Apple Inc
# 4     ABBV                   Abbvie Inc
# ..     ...                          ...
# 497    YUM                  Yum! Brands
# 498    ZBH                Zimmer Biomet
# 499   ZBRA                        Zebra
# 500   ZION                Zions Bancorp
# 501    ZTS                       Zoetis
#
# [502 rows x 2 columns]

# %% [markdown]
# FULL DATABASE CREATION

# %%
acciones_full['symbol'].loc[5]
# Out:
# 'ABC'

# %%
bridge1 = pd.DataFrame() 

for i in range(len(acciones_full))[:4]:
  symbol = acciones_full['symbol'].loc[i]
  data = ts.get_weekly_adjusted(symbol)
  datos9 =data[0]
  datos9['symbol'] = acciones_full['symbol'].loc[i]
  datos9['companyName'] = acciones_full['companyName'].loc[i]
  bridge1 = bridge1.append([datos9])
  
bridge1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-8f5494188260> in <module>()
#       3 for i in range(len(acciones_full))[:4]:
#       4   symbol = acciones_full['symbol'].loc[i]
# ----> 5   data = ts.get_weekly_adjusted(symbol)
#       6   datos9 =data[0]
#       7   datos9['symbol'] = acciones_full['symbol'].loc[i]
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _handle_api_call(self, url)
#     361                 raise ValueError(json_response["Information"])
#     362             elif "Note" in json_response and self.treat_info_as_error:
# --> 363                 raise ValueError(json_response["Note"])
#     364             return json_response
#     365         else:
#
# ValueError: Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.

# %%
pd.set_option('display.max_rows',50)
bridge1
# Out:
#             1. open  2. high   3. low  4. close  5. adjusted close  \
# date
# 2022-03-11   133.55   136.44  127.540    130.31           130.3100
# 2022-03-04   132.03   138.00  129.155    133.89           133.8900
# 2022-02-25   130.87   134.37  123.060    133.73           133.7300
# 2022-02-18   136.96   138.06  129.710    132.05           132.0500
# 2022-02-11   141.50   145.10  136.240    137.20           137.2000
# ...             ...      ...      ...       ...                ...
# 1999-12-10   114.56   118.00   99.000    103.00             0.7874
# 1999-12-03    94.25   115.56   93.250    115.00             0.8791
# 1999-11-26    91.75    95.50   88.500     95.06             0.7267
# 1999-11-19    89.62    94.75   88.060     92.44             0.7066
# 1999-11-12    87.75    97.73   86.750     90.62             0.6927
#
#              6. volume  7. dividend amount symbol                companyName
# date
# 2022-03-11  10306468.0                 0.0      A  Agilent Technologies Inc.
# 2022-03-04  15034255.0                 0.0      A  Agilent Technologies Inc.
# 2022-02-25  13557640.0                 0.0      A  Agilent Technologies Inc.
# 2022-02-18  13952999.0                 0.0      A  Agilent Technologies Inc.
# 2022-02-11   6562058.0                 0.0      A  Agilent Technologies Inc.
# ...                ...                 ...    ...                        ...
# 1999-12-10  25152800.0                 0.0   AAPL                  Apple Inc
# 1999-12-03  28046300.0                 0.0   AAPL                  Apple Inc
# 1999-11-26   9757600.0                 0.0   AAPL                  Apple Inc
# 1999-11-19  13711000.0                 0.0   AAPL                  Apple Inc
# 1999-11-12  25776200.0                 0.0   AAPL                  Apple Inc
#
# [4246 rows x 9 columns]

# %% [markdown]
# LECTURA DE DATOS DE TIPO FUNDAMENTAL DE ALPHA VANTAGE

# %%
from alpha_vantage.fundamentaldata import FundamentalData
key = 'S3DCI8BVT4ZHI0EI'
fd = FundamentalData(key, output_format = 'pandas')
data = fd.get_income_statement_annual('AAPL')
datos_f = data[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-78f554e03469> in <module>()
#       2 key = 'S3DCI8BVT4ZHI0EI'
#       3 fd = FundamentalData(key, output_format = 'pandas')
# ----> 4 data = fd.get_income_statement_annual('AAPL')
#       5 datos_f = data[0]
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _handle_api_call(self, url)
#     361                 raise ValueError(json_response["Information"])
#     362             elif "Note" in json_response and self.treat_info_as_error:
# --> 363                 raise ValueError(json_response["Note"])
#     364             return json_response
#     365         else:
#
# ValueError: Thank you for using Alpha Vantage! Our standard API call frequency is 5 calls per minute and 500 calls per day. Please visit https://www.alphavantage.co/premium/ if you would like to target a higher API call frequency.

# %%
df = pd.DataFrame(datos_f)
df.T
