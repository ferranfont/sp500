# %% [markdown]
# <a href="https://colab.research.google.com/github/ferranfont/sp500/blob/main/feed_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Alphan Vantage API KEY : S3DCI8BVT4ZHI0EI

# %%
pip install alpha_vantage

# %%
import pandas as pd
import matplotlib.pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %%
API_key = 'S3DCI8BVT4ZHI0EI'
ts = TimeSeries(key = API_key, output_format='pandas')

# %%
simbolo = 'A'
data = ts.get_daily_adjusted(simbolo)
datos =data[0]
datos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-eef0f2c9ec28> in <module>()
#       1 simbolo = 'A'
# ----> 2 data = ts.get_daily_adjusted(simbolo)
#       3 datos =data[0]
#       4 datos
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# ...

# %%
datos['1. open']
# Out:
# date
# 2022-03-11    181.03
# 2022-03-04    198.58
# 2022-02-25    205.00
# 2022-02-18    213.00
# 2022-02-11    205.79
#                ...
# 1999-12-10     40.00
# 1999-12-03     40.81
# 1999-11-26     43.50
# 1999-11-19     40.50
# 1999-11-12     44.00
# Name: 1. open, Length: 1166, dtype: float64

# %%
df = pd.DataFrame(datos)
df
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  \
# date
# 2022-03-11   163.36   165.02  154.50    154.73           154.7300
# 2022-03-04   163.06   168.91  161.97    163.17           163.1700
# 2022-02-25   164.98   166.69  152.00    164.85           164.8500
# 2022-02-18   167.37   173.34  166.19    167.30           167.3000
# 2022-02-11   172.86   176.65  168.04    168.64           168.6400
# ...             ...      ...     ...       ...                ...
# 1999-12-10   114.56   118.00   99.00    103.00             0.7874
# 1999-12-03    94.25   115.56   93.25    115.00             0.8791
# 1999-11-26    91.75    95.50   88.50     95.06             0.7267
# 1999-11-19    89.62    94.75   88.06     92.44             0.7066
# 1999-11-12    87.75    97.73   86.75     90.62             0.6927
#
#               6. volume  7. dividend amount
# date
# 2022-03-11  521334165.0                 0.0
# 2022-03-04  418753837.0                 0.0
# ...

# %%
my_columns =['open','high','low','close','adj_close','Volume','dividend']
df.columns= my_columns

# %%
df.head(10)
# Out:
#               open      high     low   close  adj_close       Volume  dividend
# date
# 2022-03-11  163.36  165.0200  154.50  154.73   154.7300  521334165.0      0.00
# 2022-03-04  163.06  168.9100  161.97  163.17   163.1700  418753837.0      0.00
# 2022-02-25  164.98  166.6900  152.00  164.85   164.8500  413588646.0      0.00
# 2022-02-18  167.37  173.3400  166.19  167.30   167.3000  364011266.0      0.00
# 2022-02-11  172.86  176.6500  168.04  168.64   168.6400  412902045.0      0.00
# 2022-02-04  170.16  176.2399  169.51  172.39   172.3900  458553231.0      0.22
# 2022-01-28  160.02  170.3500  154.70  170.33   170.1129  688670659.0      0.00
# 2022-01-21  171.51  172.5400  162.30  162.41   162.2030  397684401.0      0.00
# 2022-01-14  169.08  177.1800  168.17  173.07   172.8494  422454950.0      0.00
# 2022-01-07  177.83  182.9400  171.03  172.17   171.9506  482162362.0      0.00

# %%
#visualize data in a chart
plt.figure(figsize=(28,8))
plt.title('Precios de Apple al cierre')
plt.xlabel('Fecha',fontsize=16)
plt.ylabel('Precios de cierre',fontsize=16)
plt.plot(df['close'])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
acciones_full = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/sp500_excell.xlsx')
acciones_full
# Out:
#     symbol                  companyName
# 0        A    Agilent Technologies Inc.
# 1      AAL  American Airlines Group Inc
# 2      AAP       Advance Auto Parts Inc
# 3     AAPL                    Apple Inc
# 4     ABBV                   Abbvie Inc
# ..     ...                          ...
# 497    YUM                  Yum! Brands
# 498    ZBH                Zimmer Biomet
# 499   ZBRA                        Zebra
# 500   ZION                Zions Bancorp
# 501    ZTS                       Zoetis
#
# [502 rows x 2 columns]

# %% [markdown]
# FULL DATABASE CREATION

# %%
acciones_full['symbol'].loc[5]
# Out:
# 'ABC'

# %%
data = ts.get_daily_adjusted('A')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-0fd179901870> in <module>()
#       1
# ----> 2 data = ts.get_daily_adjusted('A')
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
# ...

# %%
bridge1 = pd.DataFrame() 

for i in range(len(acciones_full))[:3]:
  symbol = acciones_full['symbol'].loc[i]
  print(symbol)

  simbolo = 'A'
  data = ts.get_daily_adjusted(simbolo)
  #datos =data[0]
  
  datos9 =data[0]
  #bridge1 = bridge1.append([datos9])
  

datos9
# Out:
# A
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-e216f657abe6> in <module>()
#       6
#       7   simbolo = 'A'
# ----> 8   data = ts.get_daily_adjusted(simbolo)
#       9   #datos =data[0]
#      10
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     217         def _format_wrapper(self, *args, **kwargs):
#     218             call_response, data_key, meta_data_key = func(
# --> 219                 self, *args, **kwargs)
#     220             if 'json' in self.output_format.lower() or 'pandas' \
#     221                     in self.output_format.lower():
#
# /usr/local/lib/python3.7/dist-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}{}'.format(url, apikey_parameter)
# ...

# %%
bridge1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
datos9
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# date
# 2022-03-11    33.73    34.39  31.780     31.90            31.9000  56246029.0
# 2022-03-04    30.49    33.53  30.390     33.47            33.0378  54667436.0
# 2022-02-25    30.75    30.75  28.935     30.69            30.2937  43944475.0
# 2022-02-18    30.71    30.74  29.305     29.62            29.2375  37238176.0
# 2022-02-11    30.55    31.02  30.000     30.71            30.3135  45877612.0
# ...             ...      ...     ...       ...                ...         ...
# 1999-12-10    33.74    33.86  30.160     30.78            10.3980  12377600.0
# 1999-12-03    32.93    34.48  32.310     33.43            11.2389   8757300.0
# 1999-11-26    35.41    35.60  32.000     32.87            11.0506   7543800.0
# 1999-11-19    35.60    36.84  34.170     35.66            11.9886  11735700.0
# 1999-11-12    33.74    36.22  33.670     35.66            11.9886   7913900.0
#
# ...

# %%
bridge1 = pd.DataFrame() 
for i in range(3):
  symbol = acciones_full['symbol'].loc[i]
  print(symbol)
  #api_url = f'https://sandbox.iexapis.com/stable/stock/{symbol}/quote?token=Tpk_059b97af715d417d9f49f50b51b1c448'
  API_key = 'S3DCI8BVT4ZHI0EI'
  ts = TimeSeries(key = API_key, output_format='pandas')
  data = ts.get_weekly_adjusted('AAPL')
  datos =data[i]
  data['1. open']

  
  #data = ts.get_weekly_adjusted(symbol)
  
  datos =data[0]
  datos[0]
  
  print(acciones_full['companyName'])
  #data = requests.get(api_url).json()
  #print(data['companyName'])
  #bridge1 = bridge1.append([data])
# Out:
# A
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-21e743865225> in <module>()
#       8   data = ts.get_weekly_adjusted('AAPL')
#       9   datos =data[i]
# ---> 10   data['1. open']
#      11
#      12
#
# TypeError: tuple indices must be integers or slices, not str

# %% [markdown]
# LECTURA DE DATOS DE TIPO FUNDAMENTAL DE ALPHA VANTAGE

# %%
from alpha_vantage.fundamentaldata import FundamentalData
key = 'S3DCI8BVT4ZHI0EI'
fd = FundamentalData(key, output_format = 'pandas')
data = fd.get_income_statement_annual('AAPL')
datos_f = data[0]

# %%
df = pd.DataFrame(datos_f)
df.T
